# %%
import numpy as np
import matplotlib.pyplot as plt

# --- Data and Parameters ---
kx_length = 51
num_eigvals = 24
N = 100


plt.rcParams.update({'figure.autolayout': True})
plt.figure(figsize=(3.7, 5))
plt.rcParams["font.family"] = "DejaVu Serif"
plt.rcParams["mathtext.fontset"] = "dejavuserif"

data = np.loadtxt(f"band_kx_N{N}_L300.dat")

cmap = plt.cm.Blues
colors = cmap([0.85, 0.65, 0.45])


for i in range(1, num_eigvals + 1):
    plt.plot(data[:, 0], data[:, i] * 1000,color = colors[0])



plt.xlabel(r"$k_x (\AA^{-1})$", fontsize=18)
plt.ylabel("Energy (meV)", fontsize=18)
# plt.axhline(y=0, ls='--', color='k')
plt.axvline(x=0, ls='--', color='k')
plt.ylim(-31, 0)
plt.xlim(-0.02, 0.02)

plt.tick_params(direction='in', length=7, width=1., colors='k',
                    bottom=True, top=True, left=True, right=True, labelsize=18)

plt.tight_layout()
plt.savefig("valance_band_nw.png", dpi=300)
plt.savefig("valance_band_nw.pdf")
plt.savefig("valance_band_nw.svg")
plt.tight_layout()
plt.show()

# %%
np.linspace(-0.02, 0.02, 51)
# Out:
# array([-0.02  , -0.0192, -0.0184, -0.0176, -0.0168, -0.016 , -0.0152,
#        -0.0144, -0.0136, -0.0128, -0.012 , -0.0112, -0.0104, -0.0096,
#        -0.0088, -0.008 , -0.0072, -0.0064, -0.0056, -0.0048, -0.004 ,
#        -0.0032, -0.0024, -0.0016, -0.0008,  0.    ,  0.0008,  0.0016,
#         0.0024,  0.0032,  0.004 ,  0.0048,  0.0056,  0.0064,  0.0072,
#         0.008 ,  0.0088,  0.0096,  0.0104,  0.0112,  0.012 ,  0.0128,
#         0.0136,  0.0144,  0.0152,  0.016 ,  0.0168,  0.0176,  0.0184,
#         0.0192,  0.02  ])

# %%
data[:,0]
# Out:
# array([-0.02  , -0.0196, -0.0192, -0.0188, -0.0184, -0.018 , -0.0176,
#        -0.0172, -0.0168, -0.0164, -0.016 , -0.0156, -0.0152, -0.0148,
#        -0.0144, -0.014 , -0.0136, -0.0132, -0.0128, -0.0124, -0.012 ,
#        -0.0116, -0.0112, -0.0108, -0.0104, -0.01  , -0.0096, -0.0092,
#        -0.0088, -0.0084, -0.008 , -0.0076, -0.0072, -0.0068, -0.0064,
#        -0.006 , -0.0056, -0.0052, -0.0048, -0.0044, -0.004 , -0.0036,
#        -0.0032, -0.0028, -0.0024, -0.002 , -0.0016, -0.0012, -0.0008,
#        -0.0004,  0.    ,  0.0004,  0.0008,  0.0012,  0.0016,  0.002 ,
#         0.0024,  0.0028,  0.0032,  0.0036,  0.004 ,  0.0044,  0.0048,
#         0.0052,  0.0056,  0.006 ,  0.0064,  0.0068,  0.0072,  0.0076,
#         0.008 ,  0.0084,  0.0088,  0.0092,  0.0096,  0.01  ,  0.0104,
#         0.0108,  0.0112,  0.0116,  0.012 ,  0.0124,  0.0128,  0.0132,
#         0.0136,  0.014 ,  0.0144,  0.0148,  0.0152,  0.0156,  0.016 ,
# ...
