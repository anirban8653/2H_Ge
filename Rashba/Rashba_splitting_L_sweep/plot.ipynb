# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({
    "figure.figsize": [5, 4],
    "font.family": "Serif",
    "mathtext.fontset": "dejavuserif"
})

N = 50 
kx = 0.0005
Nband = 10
Ny = Nz = N
Ef_values = [0.1e-5, 0.12e-5, 0.15e-5]
styles = [
    ("o-",  "blue",  r"$\mathcal{E}_z = 0.010~\mathrm{V/\mu m}$"),
    ("s--", "red",   r"$\mathcal{E}_z = 0.012~\mathrm{V/\mu m}$"),
    ("^-.", "green", r"$\mathcal{E}_z = 0.015~\mathrm{V/\mu m}$"),
]

for Ef, (style, color, label) in zip(Ef_values, styles):

    filename = f"Pymablock_Y_kx{kx}_E_{(Ef*10000):.3f}_N{N}.dat"
    data = np.loadtxt(filename, comments="#")

    L_nm = data[:, 0]
    alpha_eVA = data[:, 1]
    alpha_meV_nm = alpha_eVA * 100.0

    plt.plot(
        L_nm,
        alpha_meV_nm,
        style,
        color=color,
        markersize=6,
        linewidth=2,
        markerfacecolor="none",
        label=label
    )

plt.xlabel(r"$L$ (nm)", fontsize=16)
plt.ylabel(r"$|\alpha^y_R|$ (meV nm)", fontsize=16)
plt.tick_params(direction="in", top=True, right=True, length=6, labelsize=16)
plt.ylim(0.03,0.06)

plt.legend(
    loc = 'upper right',
    fontsize=10,
    frameon=True,
    fancybox=False,
    edgecolor="black",
    framealpha=0.7,
)
plt.text(
    20, 0.057,
    fr"$k_x$ = {kx}" + r" $\AA^{-1}$",
    fontsize=10,
)

plt.tight_layout()
plt.savefig("alpha_vs_L_Pymablock_Y_N50_E.png", dpi=300, bbox_inches="tight")
plt.savefig("alpha_vs_L_Pymablock_Y_N50_E.pdf", bbox_inches="tight")

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({
    "figure.figsize": [5, 4],
    "font.family": "Serif",
    "mathtext.fontset": "dejavuserif"
})

N = 50 
kx = 0.0005
Nband = 10
Ny = Nz = N
Ef_values = [0.1e-5, 0.12e-5, 0.15e-5]
styles = [
    ("o-",  "blue",  r"$\mathcal{E}_z = 0.010~\mathrm{V/\mu m}$"),
    ("s--", "red",   r"$\mathcal{E}_z = 0.012~\mathrm{V/\mu m}$"),
    ("^-.", "green", r"$\mathcal{E}_z = 0.015~\mathrm{V/\mu m}$"),
]

for Ef, (style, color, label) in zip(Ef_values, styles):

    filename = f"Pymablock_Z_kx{kx}_E_{(Ef*10000):.3f}_N{N}.dat"
    data = np.loadtxt(filename, comments="#")

    L_nm = data[:, 0]
    alpha_eVA = data[:, 1]
    alpha_meV_nm = alpha_eVA * 100.0

    plt.plot(
        L_nm,
        alpha_meV_nm,
        style,
        color=color,
        markersize=6,
        linewidth=2,
        markerfacecolor="none",
        label=label
    )

plt.xlabel(r"$L$ (nm)", fontsize=16)
plt.ylabel(r"$|\alpha^y_R|$ (meV nm)", fontsize=16)
plt.tick_params(direction="in", top=True, right=True, length=6, labelsize=16)

plt.legend(
    loc = 'upper right',
    fontsize=10,
    frameon=True,
    fancybox=False,
    edgecolor="black",
    framealpha=0.7,
)
plt.text(
    60, 0.012,
    fr"$k_x$ = {kx}" + r" $\AA^{-1}$",
    fontsize=10,
)

plt.tight_layout()
plt.savefig("alpha_vs_L_Pymablock_Z_N50_E.png", dpi=300, bbox_inches="tight")
plt.savefig("alpha_vs_L_Pymablock_Z_N50_E.pdf", bbox_inches="tight")

# %%
import numpy as np
import matplotlib.pyplot as plt

# ======= PLOT SETTINGS =======
plt.rcParams.update({
    "figure.figsize": [8, 3.5],
    "font.family": "Serif",
    "mathtext.fontset": "dejavuserif",
    "axes.linewidth": 0.8
})

cmap_blue = plt.cm.Blues
cmap_red = plt.cm.Reds
blue_colors = cmap_blue([0.5, 0.7, 0.9])
red_colors  = cmap_red([0.5, 0.7, 0.9])

# ==================================================
# Parameters for the two calculations
# ==================================================
# Y-direction data
N_y = 50
kx_y = 0.0005
Ef_y = 0.1e-5

# Z-direction data
N_z = 50
kx_z = 0.0005
Ef_z = 0.1e-5

# ==================================================
# Load data
# ==================================================
filename_y = f"Pymablock_Y_kx{kx_y}_E_{(Ef_y*10000):.3f}_N{N_y}.dat"
filename_z = f"Pymablock_Z_kx{kx_z}_E_{(Ef_z*10000):.3f}_N{N_z}.dat"

data_y = np.loadtxt(filename_y, comments="#")
data_z = np.loadtxt(filename_z, comments="#")

L_y_nm = data_y[:, 0]
alpha_y_eVA = data_y[:, 1]

L_z_nm = data_z[:, 0]
alpha_z_eVA = data_z[:, 1]

# ==================================================
# Convert alpha: eV Angstrom -> meV nm
# 1 eV Angstrom = 100 meV nm
# ==================================================
alpha_y_meV_nm = np.abs(alpha_y_eVA * 100.0)
alpha_z_meV_nm = np.abs(alpha_z_eVA * 100.0)

# ======= CREATE 1x2 GRID =======
fig, (ax1, ax2) = plt.subplots(1, 2)

# --- Left Plot: Y Direction ---
ax1.plot(
    L_y_nm,
    alpha_y_meV_nm,
    'o-',
    color=blue_colors[2],
    label=r"$\alpha_y$",
    markersize=5,
    markerfacecolor='None'
)
ax1.set_ylabel(r"$|\alpha_R^y|$ (meV nm)", fontsize=16)

# --- Right Plot: Z Direction ---
ax2.plot(
    L_z_nm,
    alpha_z_meV_nm,
    'o-',
    color=blue_colors[2],
    label=r"$\alpha_z$",
    markersize=5,
    markerfacecolor='None'
)
ax2.set_ylabel(r"$|\alpha_R^z|$ (meV nm)", fontsize=16)

# --- Common Formatting ---
for ax in [ax1, ax2]:
    ax.set_xlabel(r"$L$ (nm)", fontsize=16)
    ax.tick_params(direction='in', length=6, width=0.8,
                   top=True, right=True, labelsize=14)
    ax.set_xticks([20, 40, 60, 80])

# Optional fixed y-ticks, adjust/remove depending on your data range
ax1.set_yticks([0.032, 0.033, 0.034, 0.035])
ax2.set_yticks([0.001, 0.005, 0.009, 0.013])

# --- Text annotations ---
ax1.text(0.4, 0.90,
         r"$\mathcal{E}_y$ = " + f"{Ef_y*10000:.2f}" + r" V/$\mu$m",
         transform=ax1.transAxes, fontsize=14)
ax1.text(0.4, 0.80,
         r"$k_x$ = " + f"{kx_y}" + r" $\AA^{-1}$",
         transform=ax1.transAxes, fontsize=14)

ax2.text(0.4, 0.90,
         r"$\mathcal{E}_z$ = " + f"{Ef_z*10000:.2f}" + r" V/$\mu$m",
         transform=ax2.transAxes, fontsize=14)
ax2.text(0.4, 0.80,
         r"$k_x$ = " + f"{kx_z}" + r" $\AA^{-1}$",
         transform=ax2.transAxes, fontsize=14)

# --- Panel labels (a), (b) ---
ax1.text(-0.35, 1.05, "(c)", transform=ax1.transAxes,
         fontsize=16, va='top')
ax2.text(-0.35, 1.05, "(d)", transform=ax2.transAxes,
         fontsize=16, va='top')

# --- Layout ---
plt.tight_layout()
plt.subplots_adjust(wspace=0.4)

# Save
plt.savefig(f"alpha_vs_L_YZ_Ny{N_y}_Nz{N_z}.png", dpi=300)
plt.savefig(f"alpha_vs_L_YZ_Ny{N_y}_Nz{N_z}.pdf", dpi=300)
plt.show()
